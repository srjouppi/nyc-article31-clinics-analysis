# %%
import re
import os
import pandas as pd
import requests
api_key = "MY API KEY"
from tqdm import tqdm
# Out:
# /Users/shelbyjouppi/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv("nyc_child_adolescent_clinics_addresses.csv",dtype={'site_zip_code':'str'})
df.site_zip_code = df.site_zip_code.str[:5]
df.head()
# Out:
#   program_region program_county                            sponsor_name  \
# 0  New York City          Bronx                    Acacia Network, Inc.
# 1  New York City          Bronx         Association to Benefit Children
# 2  New York City          Bronx  Astor Services for Children & Families
# 3  New York City          Bronx  Astor Services for Children & Families
# 4  New York City          Bronx  Astor Services for Children & Families
#
#                               agency_name  \
# 0                           PROMESA, Inc.
# 1         Association to Benefit Children
# 2  Astor Services for Children & Families
# 3  Astor Services for Children & Families
# 4  Astor Services for Children & Families
#
#                                           site_name main_site  \
# 0                  Westchester Center of Excellence         Y
# 1                            Fast Break - The Bronx         Y
# 2                               Astor @ Mott Hall V         N
# 3           Astor Clinic Treatment Program - Tilden         Y
# 4  Astor Services @ MS 80, The Isabel Rooney School         N
#
#                          site_address site_city site_state site_zip_code  \
# 0    915 Westchester Avenue 2nd Floor     Bronx         NY         10459
# 1                  1366 Inwood Avenue     Bronx         NY         10452
# 2    1551 East 172nd Street Room 216C     Bronx         NY         10472
# 3                   750 Tilden Street     Bronx         NY         10467
# 4  149 East Mosholu Parkway Room 414C     Bronx         NY         10467
#
#   site_county       population_simple       type
# 0       Bronx  Children & Adolescents  Community
# 1       Bronx  Children & Adolescents  Community
# 2       Bronx  Children & Adolescents  Community
# 3       Bronx  Children & Adolescents  Community
# 4       Bronx             Adolescents     School

# %%
df['full_address'] = df.site_address + ", " + df.site_city + ", " + df.site_state + " " + df.site_zip_code
df.head()
# Out:
#   program_region program_county                            sponsor_name  \
# 0  New York City          Bronx                    Acacia Network, Inc.
# 1  New York City          Bronx         Association to Benefit Children
# 2  New York City          Bronx  Astor Services for Children & Families
# 3  New York City          Bronx  Astor Services for Children & Families
# 4  New York City          Bronx  Astor Services for Children & Families
#
#                               agency_name  \
# 0                           PROMESA, Inc.
# 1         Association to Benefit Children
# 2  Astor Services for Children & Families
# 3  Astor Services for Children & Families
# 4  Astor Services for Children & Families
#
#                                           site_name main_site  \
# 0                  Westchester Center of Excellence         Y
# 1                            Fast Break - The Bronx         Y
# 2                               Astor @ Mott Hall V         N
# 3           Astor Clinic Treatment Program - Tilden         Y
# 4  Astor Services @ MS 80, The Isabel Rooney School         N
#
#                          site_address site_city site_state site_zip_code  \
# 0    915 Westchester Avenue 2nd Floor     Bronx         NY         10459
# 1                  1366 Inwood Avenue     Bronx         NY         10452
# 2    1551 East 172nd Street Room 216C     Bronx         NY         10472
# 3                   750 Tilden Street     Bronx         NY         10467
# 4  149 East Mosholu Parkway Room 414C     Bronx         NY         10467
#
#   site_county       population_simple       type  \
# 0       Bronx  Children & Adolescents  Community
# 1       Bronx  Children & Adolescents  Community
# 2       Bronx  Children & Adolescents  Community
# 3       Bronx  Children & Adolescents  Community
# 4       Bronx             Adolescents     School
#
#                                         full_address
# 0  915 Westchester Avenue 2nd Floor, Bronx, NY 10459
# 1                1366 Inwood Avenue, Bronx, NY 10452
# 2  1551 East 172nd Street Room 216C, Bronx, NY 10472
# 3                 750 Tilden Street, Bronx, NY 10467
# 4  149 East Mosholu Parkway Room 414C, Bronx, NY ...

# %%
print(df.shape)
# Out:
# (487, 14)

# %%
addresses = df.drop_duplicates(subset="full_address").full_address.to_list()
print(len(addresses))
addresses[0:5]
# Out:
# 483
# ['915 Westchester Avenue 2nd Floor, Bronx, NY 10459',
#  '1366 Inwood Avenue, Bronx, NY 10452',
#  '1551 East 172nd Street Room 216C, Bronx, NY 10472',
#  '750 Tilden Street, Bronx, NY 10467',
#  '149 East Mosholu Parkway Room 414C, Bronx, NY 10467']

# %%
# Here is a loop that goes to different addresses
# And gathers up the information we want from the Google API requests
# time.sleep is putting in a one second pause between requests
# So that we don't overload Google's server (You want to do this if you're getting a lot of stuff)
# Because APIs often have limits on how many times you can send requests or how often

# this "list" (arrays are called lists in Python) gathers the results
results_array = []
bad_addresses = []
import time

for place in tqdm(addresses):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json'
        keys = {'address': place, 'key': api_key}
        r = requests.get(url,params=keys)
        result_dic = r.json()        
        
        each_result = {}
        each_result['address'] = place
        each_result['lat'] = result_dic['results'][0]['geometry']['location']['lat']
        each_result['long'] = result_dic['results'][0]['geometry']['location']['lng']
        
    # make geometry geojson friendly
        point_geo = []
        point_geo.append(result_dic['results'][0]['geometry']['location']['lng'])
        point_geo.append(result_dic['results'][0]['geometry']['location']['lat'])
        each_result['geometry'] = point_geo
        
    # save the result
        results_array.append(each_result)
        df_good = pd.DataFrame(results_array)
        df_good.to_csv('nyc-clinics-geocoded.csv',index=False)
        
    # sleep
        time.sleep(1)
        
    except:
        bad_addresses.append(place)
        df_bad = pd.DataFrame(bad_addresses)
        df_bad.to_csv('nyc-clinics-bad-addresses.csv',index=False)
        print(f"Couldn't find {place}")
# Out:
# 100%|█████████████████████████████████████████| 483/483 [10:50<00:00,  1.35s/it]

# %%
df_geocoded = df.merge(df_good,left_on='full_address',right_on='address').drop({'address'},axis=1)
df_geocoded
# Out:
#     program_region program_county  \
# 0    New York City          Bronx
# 1    New York City          Bronx
# 2    New York City          Bronx
# 3    New York City          Bronx
# 4    New York City          Bronx
# ..             ...            ...
# 482  New York City       Richmond
# 483  New York City       Richmond
# 484  New York City       Richmond
# 485  New York City       Richmond
# 486  New York City       Richmond
#
#                                           sponsor_name  \
# 0                                 Acacia Network, Inc.
# 1                      Association to Benefit Children
# 2               Astor Services for Children & Families
# 3               Astor Services for Children & Families
# 4               Astor Services for Children & Families
# ..                                                 ...
# 482  Richmond Medical Center dba Richmond Universit...
# 483  Richmond Medical Center dba Richmond Universit...
# 484  Richmond Medical Center dba Richmond Universit...
# 485  Richmond Medical Center dba Richmond Universit...
# 486  Richmond Medical Center dba Richmond Universit...
#
#                                   agency_name  \
# 0                               PROMESA, Inc.
# 1             Association to Benefit Children
# 2      Astor Services for Children & Families
# 3      Astor Services for Children & Families
# 4      Astor Services for Children & Families
# ..                                        ...
# 482  Richmond Medical Center dba Richmond UMC
# 483  Richmond Medical Center dba Richmond UMC
# 484  Richmond Medical Center dba Richmond UMC
# 485  Richmond Medical Center dba Richmond UMC
# 486  Richmond Medical Center dba Richmond UMC
#
#                                             site_name main_site  \
# 0                    Westchester Center of Excellence         Y
# 1                              Fast Break - The Bronx         Y
# 2                                 Astor @ Mott Hall V         N
# 3             Astor Clinic Treatment Program - Tilden         Y
# 4    Astor Services @ MS 80, The Isabel Rooney School         N
# ..                                                ...       ...
# 482                           Port Richmond Satellite         N
# 483                                   Pouch Satellite         N
# 484               SIMHS Chait Clinic of RUMC @ Pediat         N
# 485     Staten Island MH Society CHAIT Clinic of RUMC         Y
# 486                              West Brighton Clinic         Y
#
#                                      site_address      site_city site_state  \
# 0                915 Westchester Avenue 2nd Floor          Bronx         NY
# 1                              1366 Inwood Avenue          Bronx         NY
# 2                1551 East 172nd Street Room 216C          Bronx         NY
# 3                               750 Tilden Street          Bronx         NY
# 4              149 East Mosholu Parkway Room 414C          Bronx         NY
# ..                                            ...            ...        ...
# 482                    166 Lockman Avenue Room 16  Staten Island         NY
# 483  657 Castleton Avenue Administrative Building  Staten Island         NY
# 484                800 Castleton Avenue 2nd Floor  Staten Island         NY
# 485                          669 Castleton Avenue  Staten Island         NY
# 486                          690 Castleton Avenue  Staten Island         NY
#
#     site_zip_code site_county       population_simple       type  \
# 0           10459       Bronx  Children & Adolescents  Community
# 1           10452       Bronx  Children & Adolescents  Community
# 2           10472       Bronx  Children & Adolescents  Community
# 3           10467       Bronx  Children & Adolescents  Community
# 4           10467       Bronx             Adolescents     School
# ..            ...         ...                     ...        ...
# 482         10303    Richmond                Children  Community
# 483         10301    Richmond                Children  Community
# 484         10310    Richmond  Children & Adolescents     School
# 485         10301    Richmond  Children & Adolescents     School
# 486         10310    Richmond  Children & Adolescents  Community
#
#                                           full_address        lat       long  \
# 0    915 Westchester Avenue 2nd Floor, Bronx, NY 10459  40.821566 -73.898408
# 1                  1366 Inwood Avenue, Bronx, NY 10452  40.839864 -73.918820
# 2    1551 East 172nd Street Room 216C, Bronx, NY 10472  40.831887 -73.877282
# 3                   750 Tilden Street, Bronx, NY 10467  40.876675 -73.862719
# 4    149 East Mosholu Parkway Room 414C, Bronx, NY ...  40.876802 -73.881370
# ..                                                 ...        ...        ...
# 482  166 Lockman Avenue Room 16, Staten Island, NY ...  40.633147 -74.162037
# 483  657 Castleton Avenue Administrative Building, ...  40.635312 -74.103344
# 484  800 Castleton Avenue 2nd Floor, Staten Island,...  40.634491 -74.109268
# 485      669 Castleton Avenue, Staten Island, NY 10301  40.635264 -74.103762
# 486      690 Castleton Avenue, Staten Island, NY 10310  40.634542 -74.105781
#
#                              geometry
# 0           [-73.8984076, 40.8215662]
# 1           [-73.9188205, 40.8398641]
# 2           [-73.8772819, 40.8318874]
# 3            [-73.862719, 40.8766745]
# 4           [-73.8813704, 40.8768024]
# ..                                ...
# 482  [-74.16203709999999, 40.6331468]
# 483         [-74.1033443, 40.6353117]
# 484  [-74.1092682, 40.63449079999999]
# 485  [-74.10376219999999, 40.6352635]
# 486         [-74.1057811, 40.6345417]
#
# [487 rows x 17 columns]

# %%
df_geocoded.to_csv('nyc_child_adolescent_clinics_geocoded.csv',index=False)
